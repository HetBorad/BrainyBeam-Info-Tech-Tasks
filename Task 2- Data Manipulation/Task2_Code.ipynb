# %% [markdown]
# Task 2:- Data Manipulation
#
# Use broadcasting to normalize a 2D numpy array row-wse..

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("100_Sales.csv").drop(columns=['Unnamed: 9','Unnamed: 10'])
data
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
# features for normalization
features = data[['Unit_Cost', 'Total_Revenue']].values

# %%
row_sums = features.sum(axis=1, keepdims=True)

# %%
normalized_features = features / row_sums

# %%
print("Original two Features were Unit_Cost and Total_Revenue:\n", features)
print("\nRow Sums:\n", row_sums)
print("\nNormalized Features (Row-wise):\n", normalized_features)
# Out:
# Original two Features were Unit_Cost and Total_Revenue:
#  [[1.59420000e+02 2.53365400e+06]
#  [1.17110000e+02 5.76782800e+05]
#  [5.24960000e+02 1.15850259e+06]
#  [6.92000000e+00 7.55916600e+04]
#  [5.24960000e+02 3.29642502e+06]
#  [1.59420000e+02 7.59202720e+05]
#  [5.02540000e+02 2.79804649e+06]
#  [9.09300000e+01 1.24511292e+06]
#  [5.66700000e+01 4.96101100e+05]
#  [1.17110000e+02 1.35618010e+06]
#  [9.09300000e+01 1.91034400e+04]
#  [3.58400000e+01 4.55479040e+05]
#  [3.58400000e+01 9.02980640e+05]
#  [5.02540000e+02 5.99705498e+06]
#  [5.66700000e+01 4.00558730e+05]
#  [3.58400000e+01 1.82825440e+05]
#  [2.63330000e+02 3.03941440e+06]
#  [3.17900000e+01 2.57653500e+05]
#  [5.02540000e+02 2.55947410e+06]
#  [3.64690000e+02 2.49252612e+06]
#  [1.59420000e+02 1.90183600e+06]
#  [1.59420000e+02 3.24971440e+05]
#  [9.74400000e+01 3.39490500e+05]
#  [6.92000000e+00 2.04047100e+04]
#  [5.66700000e+01 4.14371100e+05]
#  [2.63330000e+02 7.93518000e+05]
# ...
